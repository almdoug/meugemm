# %%
# Importar bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Ler o arquivo BLAS.dat como CSV
df = pd.read_csv('BLAS.dat', sep=',', engine='python')
df.head()
# Out:
#    matSize    Size    Mean  Variance  Largest  Smallest  Median   SD  SD_Mean  \
# 0       32  0.0001  0.0000       0.0   0.0000    0.0000  0.0000  0.0      0.0
# 1       64  0.0005  0.0001       0.0   0.0001    0.0001  0.0001  0.0      0.0
# 2       96  0.0018  0.0004       0.0   0.0004    0.0004  0.0004  0.0      0.0
# 3      128  0.0042  0.0008       0.0   0.0008    0.0009  0.0008  0.0      0.0
# 4      160  0.0082  0.0016       0.0   0.0016    0.0016  0.0016  0.0      0.0
#
#      Skew     RMS  Kurtosis
# 0  1.0731  0.0000   -0.9202
# 1  0.4810  0.0001   -1.8557
# 2  0.2530  0.0004   -2.0186
# 3  1.0708  0.0008   -0.9230
# 4  0.7913  0.0016   -1.2822

# %%
size = df['matSize'].astype(int)
flop = df['Size'].astype(float)
timeBlas = df['Mean'].astype(float)
timeMax = df['Largest'].astype(float)
timeMin = df['Smallest'].astype(float)
flopsBlas = flop/timeBlas
flopsMin = flop/timeMax
flopsMax = flop/timeMin

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsBlas, label='Média', marker='o')
plt.plot(size, flopsMin, '--', label='Menor tempo')
plt.plot(size, flopsMax, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média, menor e maior tempo de execução - DGEMM Blas')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Ler o arquivo BLAS64.dat como CSV
df = pd.read_csv('BLAS64.dat', sep=',', engine='python')
df.head()
# Out:
#    matSize    Size    Mean  Variance  Largest  Smallest  Median      SD  \
# 0       32  0.0001  0.0002       0.0   0.0000    0.0007  0.0000  0.0003
# 1       64  0.0005  0.0001       0.0   0.0001    0.0001  0.0001  0.0000
# 2       96  0.0018  0.0003       0.0   0.0003    0.0004  0.0003  0.0000
# 3      128  0.0042  0.0006       0.0   0.0006    0.0006  0.0006  0.0000
# 4      160  0.0082  0.0013       0.0   0.0012    0.0014  0.0012  0.0001
#
#    SD_Mean    Skew     RMS  Kurtosis
# 0   0.0001  1.0733  0.0003   -0.9200
# 1   0.0000  0.5617  0.0001   -1.7416
# 2   0.0000  0.6786  0.0003   -1.5230
# 3   0.0000  0.1752  0.0006   -2.1884
# 4   0.0000  0.7735  0.0013   -1.3754

# %%
size = df['matSize'].astype(int)
flop = df['Size'].astype(float)
timeBlas64 = df['Mean'].astype(float)
timeMax = df['Largest'].astype(float)
timeMin = df['Smallest'].astype(float)
flopsBlas64 = flop/timeBlas64
flopsMin = flop/timeMax
flopsMax = flop/timeMin

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsBlas64, label='Média', marker='o')
plt.plot(size, flopsMin, '--', label='Menor tempo')
plt.plot(size, flopsMax, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média, menor e maior tempo de execução - DGEMM Blas64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsBlas64, '-.', label='Blas64')
plt.plot(size, flopsBlas, '--', label='Blas')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média - DGEMM Blas e Blas64' )
plt.legend()
plt.grid(True)
plt.show()

# %%
# Ler o arquivo BLIS.dat como CSV
df = pd.read_csv('BLIS.dat', sep=',', engine='python')
df.head()
# Out:
#    matSize    Size    Mean  Variance  Largest  Smallest  Median      SD  \
# 0       32  0.0001  0.0000       0.0   0.0000    0.0002  0.0000  0.0001
# 1       64  0.0005  0.0000       0.0   0.0000    0.0000  0.0000  0.0000
# 2       96  0.0018  0.0000       0.0   0.0000    0.0000  0.0000  0.0000
# 3      128  0.0042  0.0001       0.0   0.0001    0.0001  0.0001  0.0000
# 4      160  0.0082  0.0001       0.0   0.0001    0.0002  0.0001  0.0000
#
#    SD_Mean    Skew     RMS  Kurtosis
# 0      0.0  1.0717  0.0001   -0.9220
# 1      0.0  1.0718  0.0000   -0.9219
# 2      0.0  1.0715  0.0000   -0.9222
# 3      0.0  1.0732  0.0001   -0.9201
# 4      0.0  1.0732  0.0002   -0.9201

# %%
size = df['matSize'].astype(int)
flop = df['Size'].astype(float)
timeBlis = df['Mean'].astype(float)
timeMax = df['Largest'].astype(float)
timeMin = df['Smallest'].astype(float)
flopsBlis = flop/timeBlis
flopsMin = flop/timeMax
flopsMax = flop/timeMin

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsBlis, label='Média', marker='o')
plt.plot(size, flopsMin, '--', label='Menor tempo')
plt.plot(size, flopsMax, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média, menor e maior tempo de execução - DGEMM Blis')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Ler o arquivo BLIS.dat como CSV
df = pd.read_csv('BLIS64.dat', sep=',', engine='python')
df.head()
# Out:
#    matSize    Size    Mean  Variance  Largest  Smallest  Median     SD  \
# 0       32  0.0001  0.0013       0.0   0.0000    0.0066  0.0000  0.003
# 1       64  0.0005  0.0000       0.0   0.0000    0.0000  0.0000  0.000
# 2       96  0.0018  0.0000       0.0   0.0000    0.0001  0.0000  0.000
# 3      128  0.0042  0.0001       0.0   0.0001    0.0001  0.0001  0.000
# 4      160  0.0082  0.0001       0.0   0.0001    0.0002  0.0001  0.000
#
#    SD_Mean    Skew     RMS  Kurtosis
# 0   0.0013  1.0733  0.0030   -0.9200
# 1   0.0000  1.0709  0.0000   -0.9229
# 2   0.0000  1.0716  0.0000   -0.9221
# 3   0.0000  1.0728  0.0001   -0.9206
# 4   0.0000  1.0687  0.0001   -0.9257

# %%
size = df['matSize'].astype(int)
flop = df['Size'].astype(float)
timeBlis64 = df['Mean'].astype(float)
timeMax = df['Largest'].astype(float)
timeMin = df['Smallest'].astype(float)
flopsBlis64 = flop/timeBlis64
flopsMin = flop/timeMax
flopsMax = flop/timeMin

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsBlis64, label='Média', marker='o')
plt.plot(size, flopsMin, '--', label='Menor tempo')
plt.plot(size, flopsMax, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média, menor e maior tempo de execução - DGEMM Blis64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsBlis64, '-.', label='Blis64')
plt.plot(size, flopsBlis, '--', label='Blis')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média - DGEMM Blis e Blis64' )
plt.legend()
plt.grid(True)
plt.show()

# %%
# Ler o arquivo OBLAS.dat como CSV
df = pd.read_csv('OBLAS.dat', sep=',', engine='python')
df.head()
# Out:
#    matSize    Size    Mean  Variance  Largest  Smallest  Median      SD  \
# 0       32  0.0001  0.0001       0.0   0.0000    0.0002  0.0000  0.0001
# 1       64  0.0005  0.0000       0.0   0.0000    0.0000  0.0000  0.0000
# 2       96  0.0018  0.0000       0.0   0.0000    0.0000  0.0000  0.0000
# 3      128  0.0042  0.0001       0.0   0.0001    0.0002  0.0001  0.0001
# 4      160  0.0082  0.0001       0.0   0.0001    0.0002  0.0001  0.0000
#
#    SD_Mean    Skew     RMS  Kurtosis
# 0      0.0  1.0733  0.0001   -0.9200
# 1      0.0  0.3968  0.0000   -2.0520
# 2      0.0  1.0659  0.0000   -0.9290
# 3      0.0  1.0733  0.0001   -0.9200
# 4      0.0  1.0732  0.0001   -0.9201

# %%
size = df['matSize'].astype(int)
flop = df['Size'].astype(float)
timeOBlas = df['Mean'].astype(float)
timeMax = df['Largest'].astype(float)
timeMin = df['Smallest'].astype(float)
flopsOBlas = flop/timeOBlas
flopsMin = flop/timeMax
flopsMax = flop/timeMin

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsOBlas, label='Média', marker='o')
plt.plot(size, flopsMin, '--', label='Menor tempo')
plt.plot(size, flopsMax, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média, menor e maior tempo de execução - DGEMM OpenBlas')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Ler o arquivo OBLAS64.dat como CSV
df = pd.read_csv('OBLAS64.dat', sep=',', engine='python')
df.head()
# Out:
#    matSize    Size    Mean  Variance  Largest  Smallest  Median      SD  \
# 0       32  0.0001  0.0001       0.0   0.0000    0.0003  0.0000  0.0001
# 1       64  0.0005  0.0000       0.0   0.0000    0.0000  0.0000  0.0000
# 2       96  0.0018  0.0000       0.0   0.0000    0.0000  0.0000  0.0000
# 3      128  0.0042  0.0001       0.0   0.0001    0.0004  0.0001  0.0001
# 4      160  0.0082  0.0002       0.0   0.0001    0.0002  0.0001  0.0000
#
#    SD_Mean    Skew     RMS  Kurtosis
# 0   0.0001  1.0733  0.0001   -0.9200
# 1   0.0000  1.0416  0.0000   -0.9603
# 2   0.0000  1.0481  0.0000   -0.9496
# 3   0.0001  1.0733  0.0002   -0.9200
# 4   0.0000  0.1083  0.0002   -2.1998

# %%
size = df['matSize'].astype(int)
flop = df['Size'].astype(float)
timeOBlas64 = df['Mean'].astype(float)
timeMax = df['Largest'].astype(float)
timeMin = df['Smallest'].astype(float)
flopsOBlas64 = flop/timeOBlas64
flopsMin = flop/timeMax
flopsMax = flop/timeMin

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsOBlas64, label='Média', marker='o')
plt.plot(size, flopsMin, '--', label='Menor tempo')
plt.plot(size, flopsMax, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média, menor e maior tempo de execução - DGEMM OpenBlas')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plotar gráfico da média, menor e maior tempo de execução por matSize
plt.figure(figsize=(10,6))
plt.plot(size, flopsOBlas64, '-.', label='OpenBlas64')
plt.plot(size, flopsOBlas, '--', label='OpenBlas')
plt.xlabel('Tamanho da matriz (matSize)')
plt.ylabel('Desempenho (GFLOPS)')
plt.title('Evolução da média - DGEMM OpenBlas e OpenBlas64' )
plt.legend()
plt.grid(True)
plt.show()
