# %%
# Importar bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
# Função para ler e processar arquivos .dat
def processar_dados(arquivo, diretorio='../output/native/alternatives'):
    df = pd.read_csv(f'{diretorio}/{arquivo}', sep=',', engine='python')
    matSize = df['matSize'].astype(int)
    gflops = df['Size'].astype(float)
    tempo_medio = df['Mean'].astype(float)
    tempo_max = df['Largest'].astype(float)
    tempo_min = df['Smallest'].astype(float)
    
    # Desempenho = GFLOPS / Tempo (GFLOPS/s)
    desempenho_medio = gflops / tempo_medio
    desempenho_min = gflops / tempo_max
    desempenho_max = gflops / tempo_min
    
    return matSize, desempenho_medio, desempenho_min, desempenho_max

# %%
# ATLAS
matSize_atlas, desemp_atlas, desemp_atlas_min, desemp_atlas_max = processar_dados('output_ATLAS.dat')

plt.figure(figsize=(10,6))
plt.plot(matSize_atlas, desemp_atlas, label='Média', marker='o')
plt.plot(matSize_atlas, desemp_atlas_min, '--', label='Menor tempo')
plt.plot(matSize_atlas, desemp_atlas_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - ATLAS')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLAS
matSize_blas, desemp_blas, desemp_blas_min, desemp_blas_max = processar_dados('output_BLAS.dat')

plt.figure(figsize=(10,6))
plt.plot(matSize_blas, desemp_blas, label='Média', marker='o')
plt.plot(matSize_blas, desemp_blas_min, '--', label='Menor tempo')
plt.plot(matSize_blas, desemp_blas_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLAS')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLAS64
matSize_blas64, desemp_blas64, desemp_blas64_min, desemp_blas64_max = processar_dados('output_BLAS64.dat')

plt.figure(figsize=(10,6))
plt.plot(matSize_blas64, desemp_blas64, label='Média', marker='o')
plt.plot(matSize_blas64, desemp_blas64_min, '--', label='Menor tempo')
plt.plot(matSize_blas64, desemp_blas64_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLAS64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLIS
matSize_blis, desemp_blis, desemp_blis_min, desemp_blis_max = processar_dados('output_BLIS.dat')

plt.figure(figsize=(10,6))
plt.plot(matSize_blis, desemp_blis, label='Média', marker='o')
plt.plot(matSize_blis, desemp_blis_min, '--', label='Menor tempo')
plt.plot(matSize_blis, desemp_blis_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLIS')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLIS64
matSize_blis64, desemp_blis64, desemp_blis64_min, desemp_blis64_max = processar_dados('output_BLIS64.dat')

plt.figure(figsize=(10,6))
plt.plot(matSize_blis64, desemp_blis64, label='Média', marker='o')
plt.plot(matSize_blis64, desemp_blis64_min, '--', label='Menor tempo')
plt.plot(matSize_blis64, desemp_blis64_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLIS64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# OpenBLAS64
matSize_oblas64, desemp_oblas64, desemp_oblas64_min, desemp_oblas64_max = processar_dados('output_OpenBLAS64.dat')

plt.figure(figsize=(10,6))
plt.plot(matSize_oblas64, desemp_oblas64, label='Média', marker='o')
plt.plot(matSize_oblas64, desemp_oblas64_min, '--', label='Menor tempo')
plt.plot(matSize_oblas64, desemp_oblas64_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - OpenBLAS64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparação: BLAS vs BLAS64
plt.figure(figsize=(10,6))
plt.plot(matSize_blas, desemp_blas, '-.', label='BLAS', marker='o')
plt.plot(matSize_blas64, desemp_blas64, '--', label='BLAS64', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação: BLAS vs BLAS64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparação: BLIS vs BLIS64
plt.figure(figsize=(10,6))
plt.plot(matSize_blis, desemp_blis, '-.', label='BLIS', marker='o')
plt.plot(matSize_blis64, desemp_blis64, '--', label='BLIS64', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação: BLIS vs BLIS64')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparação Geral: Todas as implementações
plt.figure(figsize=(12,7))
plt.plot(matSize_atlas, desemp_atlas, '-', label='ATLAS', marker='o')
plt.plot(matSize_blas, desemp_blas, '-', label='BLAS', marker='s')
plt.plot(matSize_blas64, desemp_blas64, '-', label='BLAS64', marker='^')
plt.plot(matSize_blis, desemp_blis, '-', label='BLIS', marker='D')
plt.plot(matSize_blis64, desemp_blis64, '-', label='BLIS64', marker='v')
plt.plot(matSize_oblas64, desemp_oblas64, '-', label='OpenBLAS64', marker='*')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação Geral - Desempenho DGEMM')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Compilação Direta (Direct Compilation)

# %%
# ATLAS - Direct Compilation
matSize_atlas_dc, desemp_atlas_dc, desemp_atlas_dc_min, desemp_atlas_dc_max = processar_dados('output_ATLAS.dat', '../output/native/direct_compilation')

plt.figure(figsize=(10,6))
plt.plot(matSize_atlas_dc, desemp_atlas_dc, label='Média', marker='o')
plt.plot(matSize_atlas_dc, desemp_atlas_dc_min, '--', label='Menor tempo')
plt.plot(matSize_atlas_dc, desemp_atlas_dc_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - ATLAS (Direct Compilation)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLAS - Direct Compilation
matSize_blas_dc, desemp_blas_dc, desemp_blas_dc_min, desemp_blas_dc_max = processar_dados('output_BLAS.dat', '../output/native/direct_compilation')

plt.figure(figsize=(10,6))
plt.plot(matSize_blas_dc, desemp_blas_dc, label='Média', marker='o')
plt.plot(matSize_blas_dc, desemp_blas_dc_min, '--', label='Menor tempo')
plt.plot(matSize_blas_dc, desemp_blas_dc_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLAS (Direct Compilation)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLAS64 - Direct Compilation
matSize_blas64_dc, desemp_blas64_dc, desemp_blas64_dc_min, desemp_blas64_dc_max = processar_dados('output_BLAS64.dat', '../output/native/direct_compilation')

plt.figure(figsize=(10,6))
plt.plot(matSize_blas64_dc, desemp_blas64_dc, label='Média', marker='o')
plt.plot(matSize_blas64_dc, desemp_blas64_dc_min, '--', label='Menor tempo')
plt.plot(matSize_blas64_dc, desemp_blas64_dc_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLAS64 (Direct Compilation)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLIS - Direct Compilation
matSize_blis_dc, desemp_blis_dc, desemp_blis_dc_min, desemp_blis_dc_max = processar_dados('output_BLIS.dat', '../output/native/direct_compilation')

plt.figure(figsize=(10,6))
plt.plot(matSize_blis_dc, desemp_blis_dc, label='Média', marker='o')
plt.plot(matSize_blis_dc, desemp_blis_dc_min, '--', label='Menor tempo')
plt.plot(matSize_blis_dc, desemp_blis_dc_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLIS (Direct Compilation)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLIS64 - Direct Compilation
matSize_blis64_dc, desemp_blis64_dc, desemp_blis64_dc_min, desemp_blis64_dc_max = processar_dados('output_BLIS64.dat', '../output/native/direct_compilation')

plt.figure(figsize=(10,6))
plt.plot(matSize_blis64_dc, desemp_blis64_dc, label='Média', marker='o')
plt.plot(matSize_blis64_dc, desemp_blis64_dc_min, '--', label='Menor tempo')
plt.plot(matSize_blis64_dc, desemp_blis64_dc_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - BLIS64 (Direct Compilation)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# OpenBLAS64 - Direct Compilation
matSize_oblas64_dc, desemp_oblas64_dc, desemp_oblas64_dc_min, desemp_oblas64_dc_max = processar_dados('output_OpenBLAS64.dat', '../output/native/direct_compilation')

plt.figure(figsize=(10,6))
plt.plot(matSize_oblas64_dc, desemp_oblas64_dc, label='Média', marker='o')
plt.plot(matSize_oblas64_dc, desemp_oblas64_dc_min, '--', label='Menor tempo')
plt.plot(matSize_oblas64_dc, desemp_oblas64_dc_max, '--', label='Maior tempo')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Desempenho DGEMM - OpenBLAS64 (Direct Compilation)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparação Geral - Direct Compilation
plt.figure(figsize=(12,7))
plt.plot(matSize_atlas_dc, desemp_atlas_dc, '-', label='ATLAS', marker='o')
plt.plot(matSize_blas_dc, desemp_blas_dc, '-', label='BLAS', marker='s')
plt.plot(matSize_blas64_dc, desemp_blas64_dc, '-', label='BLAS64', marker='^')
plt.plot(matSize_blis_dc, desemp_blis_dc, '-', label='BLIS', marker='D')
plt.plot(matSize_blis64_dc, desemp_blis64_dc, '-', label='BLIS64', marker='v')
plt.plot(matSize_oblas64_dc, desemp_oblas64_dc, '-', label='OpenBLAS64', marker='*')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação Geral - Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Comparação: Alternatives vs Direct Compilation

# %%
# ATLAS: Alternatives vs Direct Compilation
plt.figure(figsize=(10,6))
plt.plot(matSize_atlas, desemp_atlas, '-', label='ATLAS (Alternatives)', marker='o')
plt.plot(matSize_atlas_dc, desemp_atlas_dc, '--', label='ATLAS (Direct)', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação ATLAS: Alternatives vs Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLAS: Alternatives vs Direct Compilation
plt.figure(figsize=(10,6))
plt.plot(matSize_blas, desemp_blas, '-', label='BLAS (Alternatives)', marker='o')
plt.plot(matSize_blas_dc, desemp_blas_dc, '--', label='BLAS (Direct)', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação BLAS: Alternatives vs Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLAS64: Alternatives vs Direct Compilation
plt.figure(figsize=(10,6))
plt.plot(matSize_blas64, desemp_blas64, '-', label='BLAS64 (Alternatives)', marker='o')
plt.plot(matSize_blas64_dc, desemp_blas64_dc, '--', label='BLAS64 (Direct)', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação BLAS64: Alternatives vs Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLIS: Alternatives vs Direct Compilation
plt.figure(figsize=(10,6))
plt.plot(matSize_blis, desemp_blis, '-', label='BLIS (Alternatives)', marker='o')
plt.plot(matSize_blis_dc, desemp_blis_dc, '--', label='BLIS (Direct)', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação BLIS: Alternatives vs Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# BLIS64: Alternatives vs Direct Compilation
plt.figure(figsize=(10,6))
plt.plot(matSize_blis64, desemp_blis64, '-', label='BLIS64 (Alternatives)', marker='o')
plt.plot(matSize_blis64_dc, desemp_blis64_dc, '--', label='BLIS64 (Direct)', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação BLIS64: Alternatives vs Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# OpenBLAS64: Alternatives vs Direct Compilation
plt.figure(figsize=(10,6))
plt.plot(matSize_oblas64, desemp_oblas64, '-', label='OpenBLAS64 (Alternatives)', marker='o')
plt.plot(matSize_oblas64_dc, desemp_oblas64_dc, '--', label='OpenBLAS64 (Direct)', marker='s')
plt.xlabel('Tamanho da matriz')
plt.ylabel('Desempenho (GFLOPS/s)')
plt.title('Comparação OpenBLAS64: Alternatives vs Direct Compilation')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Comparação Final: Todas as implementações (Alternatives vs Direct)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 6))

# Alternatives
ax1.plot(matSize_atlas, desemp_atlas, '-', label='ATLAS', marker='o')
ax1.plot(matSize_blas, desemp_blas, '-', label='BLAS', marker='s')
ax1.plot(matSize_blas64, desemp_blas64, '-', label='BLAS64', marker='^')
ax1.plot(matSize_blis, desemp_blis, '-', label='BLIS', marker='D')
ax1.plot(matSize_blis64, desemp_blis64, '-', label='BLIS64', marker='v')
ax1.plot(matSize_oblas64, desemp_oblas64, '-', label='OpenBLAS64', marker='*')
ax1.set_xlabel('Tamanho da matriz')
ax1.set_ylabel('Desempenho (GFLOPS/s)')
ax1.set_title('Alternatives (update-alternatives)')
ax1.legend()
ax1.grid(True)

# Direct Compilation
ax2.plot(matSize_atlas_dc, desemp_atlas_dc, '-', label='ATLAS', marker='o')
ax2.plot(matSize_blas_dc, desemp_blas_dc, '-', label='BLAS', marker='s')
ax2.plot(matSize_blas64_dc, desemp_blas64_dc, '-', label='BLAS64', marker='^')
ax2.plot(matSize_blis_dc, desemp_blis_dc, '-', label='BLIS', marker='D')
ax2.plot(matSize_blis64_dc, desemp_blis64_dc, '-', label='BLIS64', marker='v')
ax2.plot(matSize_oblas64_dc, desemp_oblas64_dc, '-', label='OpenBLAS64', marker='*')
ax2.set_xlabel('Tamanho da matriz')
ax2.set_ylabel('Desempenho (GFLOPS/s)')
ax2.set_title('Direct Compilation')
ax2.legend()
ax2.grid(True)

plt.tight_layout()
plt.show()
